# %%
print("Hello")

# %%
'''
mongodb+srv://rasi:Razi585@cluster0.bis6s.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
'''

# %%
import pandas as pd

df = pd.read_csv("Indicators_of_Anxiety_or_Depression.csv")
df.head()

# %%
df.shape

# %%
df.columns

# %%
data = df.to_dict(orient="records")
data

# %%
len(data)

# %%
DB_NAME = 'Mental_Health'
COLLECTION_NAME = "mental_health"
CONNECTION_URL = "mongodb+srv://rasi:Razi585@cluster0.bis6s.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]


collection = data_base[COLLECTION_NAME]

record = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
for i,j in enumerate(records):
    print(f"{i}: {j}")

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id                        Indicator  \
# 0  66b262690fe157cc117a6979  Symptoms of Depressive Disorder
# 1  66b262690fe157cc117a697a  Symptoms of Depressive Disorder
# 2  66b262690fe157cc117a697b  Symptoms of Depressive Disorder
# 3  66b262690fe157cc117a697c  Symptoms of Depressive Disorder
# 4  66b262690fe157cc117a697d  Symptoms of Depressive Disorder
#
#                Group          State       Subgroup Phase  Time Period  \
# 0  National Estimate  United States  United States   1.0            1
# 1             By Age  United States  18 - 29 years   1.0            1
# 2             By Age  United States  30 - 39 years   1.0            1
# 3             By Age  United States  40 - 49 years   1.0            1
# 4             By Age  United States  50 - 59 years   1.0            1
#
#       Time Period Label Time Period Start Date Time Period End Date  Value  \
# 0  Apr 23 - May 5, 2020             04/23/2020           05/05/2020   23.5
# ...

# %%
if '_id' in df.columns.to_list():
    df.drop('_id', axis=1,inplace=True)

# %%
df
# Out:
#                                                Indicator              Group  \
# 0                        Symptoms of Depressive Disorder  National Estimate
# 1                        Symptoms of Depressive Disorder             By Age
# 2                        Symptoms of Depressive Disorder             By Age
# 3                        Symptoms of Depressive Disorder             By Age
# 4                        Symptoms of Depressive Disorder             By Age
# ...                                                  ...                ...
# 16087  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16088  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16089  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16090  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16091  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
# ...
